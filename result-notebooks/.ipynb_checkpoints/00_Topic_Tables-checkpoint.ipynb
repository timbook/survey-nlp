# %% [markdown]
# # Topic Tables
# This notebook crosstabs topic predictions with each product's "Product" classification. We also show the most significant words in each model.

# %%
import numpy as np
import pandas as pd
from gensim import models
# Out:
# C:\Users\avinash.tamby\AppData\Local\Continuum\anaconda3\lib\site-packages\gensim\utils.py:1197: UserWarning: detected Windows; aliasing chunkize to chunkize_serial
#   warnings.warn("detected Windows; aliasing chunkize to chunkize_serial")

# %%
comp = pd.read_csv('../output/complaint-topics.csv')

# %% [markdown]
# #### Many product labels are very similar - we group where we believe appropriate.

# %%
productLookup = {
  'Bank account or service':'Bank Account',
  'Checking or savings account':'Bank Account',
  'Consumer Loan':'Consumer Loan',
  'Credit card':'Credit card',
  'Credit card or prepaid card':'Credit card',
  'Credit reporting':'Credit reporting',
  'Credit reporting, credit repair services, or other personal consumer reports':'Credit reporting',
  'Debt collection':'Debt collection',
  'Money transfer, virtual currency, or money service':'Money transfers',
  'Money transfers':'Money transfers',
  'Mortgage':'Mortgage',
  'Other financial service':'Other',
  'Payday loan':'Payday loan',
  'Payday loan, title loan, or personal loan':'Payday loan',
  'Prepaid card':'Credit card',
  'Student loan':'Student loan',
  'Vehicle loan or lease':'Vehicle loan or lease',
  'Virtual currency':'Money transfers'
}

# %%
comp['product_group'] = np.array([productLookup[s] for s in comp['Product']])

# %% [markdown]
# #### Tables showing text-to-product association.

# %%
pd.crosstab(comp.topic11,
            comp.product_group,
            rownames=["Predicted Topic"],
            colnames=["Product Group"],
            margins=True)
# Out:
# Product Group    Bank Account  Consumer Loan  Credit card  Credit reporting  \
# Predicted Topic
# 0                        8576            204         1235               230
# 1                         346           2031         3089              1251
# 2                        2048            151         8766               717
# 3                        2934           1441         4347              2664
# 4                          50            194          315              1531
# 5                         558            351          494              1366
# 6                         248            743         1367             11052
# 7                         304            348         1026             18084
# 8                         150            632          482              1118
# 9                         108            262           59               455
# 10                        920           3132         1294              1713
# All                     16242           9489        22474             40181
#
# Product Group    Debt collection  Money transfers  Mortgage  Other  \
# Predicted Topic
# 0                            393              728       517     65
# 1                           1182               17      7273     10
# 2                            419              125       118     15
# 3                           6052              703      5227     91
# 4                          15077                4       142     10
# 5                           2609               74      2501     15
# 6                           2360               12       754      7
# 7                           4200               12       243      3
# 8                           9923               54       307     14
# 9                            446                5     11834     21
# 10                          2672              150      6451     40
# All                        45333             1884     35367    291
#
# Product Group    Payday loan  Student loan  Vehicle loan or lease     All
# Predicted Topic
# 0                        124            64                      5   12141
# 1                        440          2374                    147   18160
# 2                         21            32                      1   12413
# 3                        394          1635                     87   25575
# 4                         67           162                      2   17554
# 5                         60           159                     28    8215
# 6                         59           344                     16   16962
# 7                         52           174                     13   24459
# 8                        406           464                     17   13567
# 9                         76          4301                      4   17571
# 10                       482          2790                    217   19861
# All                     2181         12499                    537  186478

# %%
np.round(pd.crosstab(comp.topic11,
         comp.product_group,
         rownames=["Predicted Topic"],
         colnames=["Product Group"],
         normalize = 'index'), 3)
# Out:
# Product Group    Bank Account  Consumer Loan  Credit card  Credit reporting  \
# Predicted Topic
# 0                       0.706          0.017        0.102             0.019
# 1                       0.019          0.112        0.170             0.069
# 2                       0.165          0.012        0.706             0.058
# 3                       0.115          0.056        0.170             0.104
# 4                       0.003          0.011        0.018             0.087
# 5                       0.068          0.043        0.060             0.166
# 6                       0.015          0.044        0.081             0.652
# 7                       0.012          0.014        0.042             0.739
# 8                       0.011          0.047        0.036             0.082
# 9                       0.006          0.015        0.003             0.026
# 10                      0.046          0.158        0.065             0.086
#
# Product Group    Debt collection  Money transfers  Mortgage  Other  \
# Predicted Topic
# 0                          0.032            0.060     0.043  0.005
# 1                          0.065            0.001     0.400  0.001
# 2                          0.034            0.010     0.010  0.001
# 3                          0.237            0.027     0.204  0.004
# 4                          0.859            0.000     0.008  0.001
# 5                          0.318            0.009     0.304  0.002
# 6                          0.139            0.001     0.044  0.000
# 7                          0.172            0.000     0.010  0.000
# 8                          0.731            0.004     0.023  0.001
# 9                          0.025            0.000     0.673  0.001
# 10                         0.135            0.008     0.325  0.002
#
# Product Group    Payday loan  Student loan  Vehicle loan or lease
# Predicted Topic
# 0                      0.010         0.005                  0.000
# 1                      0.024         0.131                  0.008
# 2                      0.002         0.003                  0.000
# 3                      0.015         0.064                  0.003
# 4                      0.004         0.009                  0.000
# 5                      0.007         0.019                  0.003
# 6                      0.003         0.020                  0.001
# 7                      0.002         0.007                  0.001
# 8                      0.030         0.034                  0.001
# 9                      0.004         0.245                  0.000
# 10                     0.024         0.140                  0.011

# %% [markdown]
# #### Topic Words
# Here are the most significant words associated with each topic.  From these, you can begin to get a "theme" of what each topic represents.

# %%
lda = models.LdaModel.load('../models/lda11')

# %%
def getWords(i):
    s = lda.show_topic(i)
    words = [w for (w, prob) in s]    
    return(np.array(words))

# %%
topic_words = pd.DataFrame(index=np.arange(1, 11))
for i in range(11):
    words = getWords(i)
    topic_words['Topic %2d' % i] = words
    
topic_words
# Out:
#    Topic  0  Topic  1    Topic  2 Topic  3 Topic  4   Topic  5    Topic  6  \
# 1      bank   payment        card     call     debt      state      credit
# 2   account      late       charg     told  collect        law      report
# 3     check       pay  creditcard    would      owe     consum       remov
# 4     money    amount     account   receiv  account       file       score
# 5     chase     month         use     said  compani  complaint      bureau
# 6      fund   account         one       nt    agenc     provid        show
# 7   america       due      receiv      ask   receiv      court     account
# 8   deposit      paid     purchas     back   letter   document        year
# 9       fee  interest       capit      get     bill     violat  bankruptci
# 10    close    balanc         fee    could    valid       case         neg
#
#    Topic  7 Topic  8    Topic  9 Topic 10
# 1    report     call        loan      pay
# 2   account   number     mortgag       nt
# 3    credit    phone        home      get
# 4    inform     name       modif     year
# 5    disput  compani      servic     loan
# 6   request   person    document    would
# 7     remov  contact  foreclosur     help
# 8      file     time     request     time
# 9    verifi  address        time      car
# 10   letter     stop     payment     home
