# %%
import numpy as np
import pandas as pd
import nltk

# %%
sents = pd.read_table('../output/example_sents.txt',
                      sep='|',
                      header=None,
                      names=['sent', 'assigned_topic'])

# %%
perp_table = pd.read_csv('../output/perplexity-table.csv')
perp_table['assgntopic'] = sents['assigned_topic']
perp_table['pred'] = perp_table.loc[:, 'topic_0':'topic_10'].idxmin(axis=1)

# %% [markdown]
# ## Perplexity Table
# Because certrain trigrams are so rare in irrelevant topics, trigram probabilities are nearly zero, and hence perpelxities are effectively infite. These are missing values in the data, but depicted as 0 in the table below.

# %%
np.round(perp_table.iloc[:, 1:], 2).fillna('0')
# Out:
#    topic_0 topic_1 topic_2 topic_3 topic_4 topic_5 topic_6 topic_7 topic_8  \
# 0    40.93       0       0       0   34.81       0       0       0       0
# 1        0       0       0       0   22.65       0       0       0       0
# 2        0   18.43       0       0       0    53.5       0       0       0
# 3        0       0    4.59       0   16.05   15.71    8.25       0       0
# 4        0       0       0       0       0       0       0       0   17.75
# 5        0       0       0       0       0   43.04       0   12.69       0
# 6        0    19.3       0       0       0       0       0       0       0
# 7        0       0       0       0       0   17.47       0       0   25.74
# 8        0  162.52   93.41       0       0   37.65       0       0  135.96
# 9        0       0   22.61       0       0       0       0       0       0
# 10       0       0       0       0       0       0       0       0       0
# ...
